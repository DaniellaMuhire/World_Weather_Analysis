# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
 #Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75e8cf4369c6729fa7ae4020673751a1

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country, 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | maldonado
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | litovko
# Processing Record 4 of Set 1 | quepos
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | mayumba
# Processing Record 8 of Set 1 | merauke
# Processing Record 9 of Set 1 | richards bay
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | tessalit
# Processing Record 12 of Set 1 | karratha
# Processing Record 13 of Set 1 | malakal
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | talara
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | okha
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | jumla
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | almaznyy
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | qostanay
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | klaksvik
# Processing Record 33 of Set 1 | bay roberts
# Processing Record 34 of Set 1 | quime
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | meulaboh
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 1 | mackay
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | road town
# Processing Record 46 of Set 1 | nyurba
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | pangai
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1 | halifax
# Processing Record 1 of Set 2 | kurilsk
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | mount gambier
# Processing Record 6 of Set 2 | poya
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | kongolo
# Processing Record 9 of Set 2 | gigmoto
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | lichinga
# Processing Record 12 of Set 2 | taoudenni
# Processing Record 13 of Set 2 | kingaroy
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | santa comba
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 23 of Set 2 | marigot
# Processing Record 24 of Set 2 | saint john
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | aquiraz
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | vilhena
# Processing Record 30 of Set 2 | karonga
# Processing Record 31 of Set 2 | casablanca
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | bilibino
# Processing Record 36 of Set 2 | wanning
# Processing Record 37 of Set 2 | kapoeta
# Processing Record 38 of Set 2 | pingliang
# Processing Record 39 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 2 | ulaanbaatar
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | bayonet point
# Processing Record 45 of Set 2 | busselton
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | margate
# Processing Record 48 of Set 2 | kasongo
# Processing Record 49 of Set 2 | novyy urengoy
# Processing Record 50 of Set 2 | tecoanapa
# Processing Record 1 of Set 3 | mokhsogollokh
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | panguna
# Processing Record 4 of Set 3 | dakar
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | nioro
# Processing Record 7 of Set 3 | hasaki
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | fort nelson
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | esmeraldas
# Processing Record 13 of Set 3 | muroto
# Processing Record 14 of Set 3 | gamba
# Processing Record 15 of Set 3 | cap malheureux
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | pak phanang
# Processing Record 18 of Set 3 | muros
# Processing Record 19 of Set 3 | boa vista
# Processing Record 20 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 3 | avera
# Processing Record 22 of Set 3 | warmbad
# Processing Record 23 of Set 3 | mitsamiouli
# Processing Record 24 of Set 3 | ringebu
# Processing Record 25 of Set 3 | pevek
# Processing Record 26 of Set 3 | bonavista
# Processing Record 27 of Set 3 | montepuez
# Processing Record 28 of Set 3 | gazojak
# Processing Record 29 of Set 3 | tijara
# Processing Record 30 of Set 3 | high prairie
# Processing Record 31 of Set 3 | magan
# Processing Record 32 of Set 3 | bluff
# Processing Record 33 of Set 3 | hambantota
# Processing Record 34 of Set 3 | hobart
# Processing Record 35 of Set 3 | takoradi
# Processing Record 36 of Set 3 | bambous virieux
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | louveira
# Processing Record 39 of Set 3 | kisangani
# Processing Record 40 of Set 3 | hima
# Processing Record 41 of Set 3 | alugan
# Processing Record 42 of Set 3 | lavrentiya
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | pleasant point
# Processing Record 48 of Set 3 | onalaska
# Processing Record 49 of Set 3 | yulara
# Processing Record 50 of Set 3 | traverse city
# Processing Record 1 of Set 4 | chimbote
# Processing Record 2 of Set 4 | viransehir
# Processing Record 3 of Set 4 | bathsheba
# Processing Record 4 of Set 4 | waddan
# Processing Record 5 of Set 4 | oriximina
# Processing Record 6 of Set 4 | tra vinh
# Processing Record 7 of Set 4 | jalu
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | bilma
# Processing Record 10 of Set 4 | kihurio
# Processing Record 11 of Set 4 | seymchan
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | koupela
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | karjat
# Processing Record 16 of Set 4 | san rafael del sur
# Processing Record 17 of Set 4 | lovozero
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | nome
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | aklavik
# Processing Record 22 of Set 4 | padang
# Processing Record 23 of Set 4 | shar
# Processing Record 24 of Set 4 | atuona
# Processing Record 25 of Set 4 | teguise
# Processing Record 26 of Set 4 | rocha
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | cayenne
# Processing Record 30 of Set 4 | gizo
# Processing Record 31 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 4 | dubbo
# Processing Record 33 of Set 4 | forrest city
# Processing Record 34 of Set 4 | salalah
# Processing Record 35 of Set 4 | hervey bay
# Processing Record 36 of Set 4 | diplo
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | berlevag
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | kitzingen
# Processing Record 42 of Set 4 | serenje
# Processing Record 43 of Set 4 | dvinskoy
# Processing Record 44 of Set 4 | codrington
# Processing Record 45 of Set 4 | maymanak
# City not found. Skipping...
# Processing Record 46 of Set 4 | ivdel
# Processing Record 47 of Set 4 | saint anthony
# Processing Record 48 of Set 4 | clarksburg
# Processing Record 49 of Set 4 | araouane
# Processing Record 50 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 5 | havelock
# Processing Record 2 of Set 5 | irbit
# Processing Record 3 of Set 5 | menongue
# Processing Record 4 of Set 5 | chuy
# Processing Record 5 of Set 5 | cootamundra
# Processing Record 6 of Set 5 | sola
# Processing Record 7 of Set 5 | bac can
# City not found. Skipping...
# Processing Record 8 of Set 5 | pinega
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | hualmay
# Processing Record 11 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 13 of Set 5 | oliver
# Processing Record 14 of Set 5 | arman
# Processing Record 15 of Set 5 | swan hill
# Processing Record 16 of Set 5 | nchelenge
# Processing Record 17 of Set 5 | los andes
# Processing Record 18 of Set 5 | griffith
# Processing Record 19 of Set 5 | nouadhibou
# Processing Record 20 of Set 5 | turbat
# Processing Record 21 of Set 5 | aguimes
# Processing Record 22 of Set 5 | moron
# Processing Record 23 of Set 5 | portgordon
# Processing Record 24 of Set 5 | blyth
# Processing Record 25 of Set 5 | san cristobal
# Processing Record 26 of Set 5 | acapulco
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | krasnyy chikoy
# Processing Record 29 of Set 5 | skiros
# City not found. Skipping...
# Processing Record 30 of Set 5 | srednekolymsk
# Processing Record 31 of Set 5 | nagua
# Processing Record 32 of Set 5 | hamilton
# Processing Record 33 of Set 5 | sao felix do xingu
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | stavern
# Processing Record 37 of Set 5 | tucupita
# Processing Record 38 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 5 | ust-charyshskaya pristan
# Processing Record 40 of Set 5 | sao filipe
# Processing Record 41 of Set 5 | cidreira
# Processing Record 42 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 5 | sinop
# Processing Record 44 of Set 5 | bagan
# Processing Record 45 of Set 5 | ketchikan
# Processing Record 46 of Set 5 | narsaq
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | mountain home
# Processing Record 49 of Set 5 | castro
# Processing Record 50 of Set 5 | pachora
# Processing Record 1 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 6 | buin
# Processing Record 3 of Set 6 | mindelo
# Processing Record 4 of Set 6 | puerto madryn
# Processing Record 5 of Set 6 | mouila
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | viedma
# Processing Record 8 of Set 6 | half moon bay
# Processing Record 9 of Set 6 | torbay
# Processing Record 10 of Set 6 | douglas
# Processing Record 11 of Set 6 | thunder bay
# Processing Record 12 of Set 6 | ulety
# Processing Record 13 of Set 6 | pandamatenga
# Processing Record 14 of Set 6 | letnyaya stavka
# Processing Record 15 of Set 6 | mantua
# Processing Record 16 of Set 6 | te anau
# Processing Record 17 of Set 6 | channagiri
# Processing Record 18 of Set 6 | vila franca do campo
# Processing Record 19 of Set 6 | carnarvon
# Processing Record 20 of Set 6 | nhulunbuy
# Processing Record 21 of Set 6 | platanos
# Processing Record 22 of Set 6 | asau
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | north bend
# Processing Record 25 of Set 6 | tamiahua
# Processing Record 26 of Set 6 | miandrivazo
# Processing Record 27 of Set 6 | erdenet
# Processing Record 28 of Set 6 | east bethel
# Processing Record 29 of Set 6 | vestmannaeyjar
# Processing Record 30 of Set 6 | kamien pomorski
# Processing Record 31 of Set 6 | cookshire
# City not found. Skipping...
# Processing Record 32 of Set 6 | prieska
# Processing Record 33 of Set 6 | aldan
# Processing Record 34 of Set 6 | tadine
# Processing Record 35 of Set 6 | gaoua
# Processing Record 36 of Set 6 | chimore
# Processing Record 37 of Set 6 | roma
# Processing Record 38 of Set 6 | victoria
# Processing Record 39 of Set 6 | boyolangu
# Processing Record 40 of Set 6 | sabha
# Processing Record 41 of Set 6 | karakol
# Processing Record 42 of Set 6 | coihaique
# Processing Record 43 of Set 6 | yinchuan
# Processing Record 44 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 6 | antibes
# Processing Record 46 of Set 6 | tuatapere
# Processing Record 47 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 6 | la presa
# Processing Record 49 of Set 6 | antofagasta
# Processing Record 50 of Set 6 | guymon
# Processing Record 1 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 7 | praia da vitoria
# Processing Record 3 of Set 7 | upington
# Processing Record 4 of Set 7 | kawalu
# Processing Record 5 of Set 7 | lorengau
# Processing Record 6 of Set 7 | arraial do cabo
# Processing Record 7 of Set 7 | mount hagen
# Processing Record 8 of Set 7 | mount isa
# Processing Record 9 of Set 7 | hobyo
# Processing Record 10 of Set 7 | talnakh
# Processing Record 11 of Set 7 | severo-kurilsk
# Processing Record 12 of Set 7 | bengkulu
# Processing Record 13 of Set 7 | kaohsiung
# Processing Record 14 of Set 7 | quatre cocos
# Processing Record 15 of Set 7 | kathu
# Processing Record 16 of Set 7 | kahului
# Processing Record 17 of Set 7 | hofn
# Processing Record 18 of Set 7 | oranjemund
# Processing Record 19 of Set 7 | pisco
# Processing Record 20 of Set 7 | hastings
# Processing Record 21 of Set 7 | samana
# Processing Record 22 of Set 7 | vanimo
# Processing Record 23 of Set 7 | airai
# Processing Record 24 of Set 7 | luderitz
# Processing Record 25 of Set 7 | champerico
# Processing Record 26 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 7 | harper
# Processing Record 28 of Set 7 | taseyevo
# Processing Record 29 of Set 7 | woodstock
# Processing Record 30 of Set 7 | ust-nera
# Processing Record 31 of Set 7 | oksfjord
# Processing Record 32 of Set 7 | yarmouth
# Processing Record 33 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 7 | baykit
# Processing Record 35 of Set 7 | roald
# Processing Record 36 of Set 7 | mogadishu
# Processing Record 37 of Set 7 | chiredzi
# Processing Record 38 of Set 7 | lasa
# Processing Record 39 of Set 7 | wanaka
# Processing Record 40 of Set 7 | bantou
# Processing Record 41 of Set 7 | iguape
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | laguna
# Processing Record 45 of Set 7 | mayenne
# Processing Record 46 of Set 7 | constitucion
# Processing Record 47 of Set 7 | waingapu
# Processing Record 48 of Set 7 | villarrobledo
# Processing Record 49 of Set 7 | yuci
# Processing Record 50 of Set 7 | tiksi
# Processing Record 1 of Set 8 | biak
# Processing Record 2 of Set 8 | shingu
# Processing Record 3 of Set 8 | fukue
# Processing Record 4 of Set 8 | tura
# Processing Record 5 of Set 8 | olga
# Processing Record 6 of Set 8 | muravlenko
# Processing Record 7 of Set 8 | vieques
# Processing Record 8 of Set 8 | presidente epitacio
# Processing Record 9 of Set 8 | belaya gora
# Processing Record 10 of Set 8 | kihei
# Processing Record 11 of Set 8 | atocha
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | grand-lahou
# Processing Record 14 of Set 8 | sao joao da barra
# Processing Record 15 of Set 8 | sinnamary
# Processing Record 16 of Set 8 | machaneng
# Processing Record 17 of Set 8 | beringovskiy
# Processing Record 18 of Set 8 | ayr
# Processing Record 19 of Set 8 | juneau
# Processing Record 20 of Set 8 | smolyaninovo
# Processing Record 21 of Set 8 | ust-maya
# Processing Record 22 of Set 8 | touros
# Processing Record 23 of Set 8 | souillac
# Processing Record 24 of Set 8 | gdov
# Processing Record 25 of Set 8 | matay
# Processing Record 26 of Set 8 | la palma
# Processing Record 27 of Set 8 | mildura
# Processing Record 28 of Set 8 | sidrolandia
# Processing Record 29 of Set 8 | tohana
# Processing Record 30 of Set 8 | katra
# Processing Record 31 of Set 8 | vao
# Processing Record 32 of Set 8 | dingle
# Processing Record 33 of Set 8 | zhigansk
# Processing Record 34 of Set 8 | nabire
# Processing Record 35 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 8 | lerwick
# Processing Record 37 of Set 8 | canandaigua
# Processing Record 38 of Set 8 | hadishahr
# Processing Record 39 of Set 8 | la massana
# Processing Record 40 of Set 8 | broome
# Processing Record 41 of Set 8 | bereda
# Processing Record 42 of Set 8 | comodoro rivadavia
# Processing Record 43 of Set 8 | tolaga bay
# Processing Record 44 of Set 8 | ulladulla
# Processing Record 45 of Set 8 | tela
# Processing Record 46 of Set 8 | cukai
# Processing Record 47 of Set 8 | honiara
# Processing Record 48 of Set 8 | rena
# Processing Record 49 of Set 8 | kidal
# Processing Record 50 of Set 8 | puerto ayacucho
# Processing Record 1 of Set 9 | egvekinot
# Processing Record 2 of Set 9 | campoverde
# Processing Record 3 of Set 9 | lesozavodsk
# Processing Record 4 of Set 9 | puerto del rosario
# Processing Record 5 of Set 9 | monrovia
# Processing Record 6 of Set 9 | sfantu gheorghe
# Processing Record 7 of Set 9 | kushmurun
# Processing Record 8 of Set 9 | lodwar
# Processing Record 9 of Set 9 | aksarka
# Processing Record 10 of Set 9 | aljezur
# Processing Record 11 of Set 9 | hillsboro
# Processing Record 12 of Set 9 | khandyga
# Processing Record 13 of Set 9 | owerri
# Processing Record 14 of Set 9 | novoilinsk
# Processing Record 15 of Set 9 | san carlos
# Processing Record 16 of Set 9 | ginir
# Processing Record 17 of Set 9 | bambanglipuro
# Processing Record 18 of Set 9 | shinuhayr
# Processing Record 19 of Set 9 | necochea
# Processing Record 20 of Set 9 | hoquiam
# Processing Record 21 of Set 9 | helong
# Processing Record 22 of Set 9 | nesna
# Processing Record 23 of Set 9 | puri
# Processing Record 24 of Set 9 | buraydah
# Processing Record 25 of Set 9 | slave lake
# Processing Record 26 of Set 9 | high level
# Processing Record 27 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 9 | leningradskiy
# Processing Record 29 of Set 9 | itupiranga
# Processing Record 30 of Set 9 | olafsvik
# Processing Record 31 of Set 9 | paamiut
# Processing Record 32 of Set 9 | moranbah
# Processing Record 33 of Set 9 | porto novo
# Processing Record 34 of Set 9 | miramar
# Processing Record 35 of Set 9 | saint-pierre
# Processing Record 36 of Set 9 | havoysund
# Processing Record 37 of Set 9 | puerto escondido
# Processing Record 38 of Set 9 | genhe
# Processing Record 39 of Set 9 | kodiak
# Processing Record 40 of Set 9 | peto
# Processing Record 41 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 9 | coahuayana
# Processing Record 43 of Set 9 | sorong
# Processing Record 44 of Set 9 | kirakira
# Processing Record 45 of Set 9 | nelson bay
# Processing Record 46 of Set 9 | awjilah
# Processing Record 47 of Set 9 | rabat
# Processing Record 48 of Set 9 | husavik
# Processing Record 49 of Set 9 | chara
# Processing Record 50 of Set 9 | weligama
# Processing Record 1 of Set 10 | teknaf
# Processing Record 2 of Set 10 | dunedin
# Processing Record 3 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 4 of Set 10 | rawson
# Processing Record 5 of Set 10 | kang
# Processing Record 6 of Set 10 | kutum
# Processing Record 7 of Set 10 | pauini
# Processing Record 8 of Set 10 | polyarnyy
# Processing Record 9 of Set 10 | sitka
# Processing Record 10 of Set 10 | quepem
# Processing Record 11 of Set 10 | west bay
# Processing Record 12 of Set 10 | lompoc
# Processing Record 13 of Set 10 | pemba
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | chingirlau
# Processing Record 16 of Set 10 | grand gaube
# Processing Record 17 of Set 10 | maragogi
# Processing Record 18 of Set 10 | fuyu
# Processing Record 19 of Set 10 | yola
# Processing Record 20 of Set 10 | thinadhoo
# Processing Record 21 of Set 10 | hudson bay
# Processing Record 22 of Set 10 | bara
# Processing Record 23 of Set 10 | bassar
# Processing Record 24 of Set 10 | marmora
# Processing Record 25 of Set 10 | penzance
# Processing Record 26 of Set 10 | qasigiannguit
# Processing Record 27 of Set 10 | juegang
# Processing Record 28 of Set 10 | linjiang
# Processing Record 29 of Set 10 | teluk nibung
# Processing Record 30 of Set 10 | taltal
# Processing Record 31 of Set 10 | grand forks
# Processing Record 32 of Set 10 | sechura
# Processing Record 33 of Set 10 | pennagaram
# Processing Record 34 of Set 10 | emba
# Processing Record 35 of Set 10 | tocopilla
# Processing Record 36 of Set 10 | najran
# Processing Record 37 of Set 10 | bonthe
# Processing Record 38 of Set 10 | kamen-na-obi
# Processing Record 39 of Set 10 | nantucket
# Processing Record 40 of Set 10 | coquimbo
# Processing Record 41 of Set 10 | camacha
# Processing Record 42 of Set 10 | liwale
# Processing Record 43 of Set 10 | srandakan
# Processing Record 44 of Set 10 | korla
# Processing Record 45 of Set 10 | portland
# Processing Record 46 of Set 10 | luau
# Processing Record 47 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 10 | taos
# Processing Record 49 of Set 10 | zimovniki
# Processing Record 50 of Set 10 | paysandu
# Processing Record 1 of Set 11 | moindou
# Processing Record 2 of Set 11 | vorotynets
# Processing Record 3 of Set 11 | kouroussa
# Processing Record 4 of Set 11 | umarkot
# Processing Record 5 of Set 11 | aswan
# Processing Record 6 of Set 11 | cabedelo
# Processing Record 7 of Set 11 | anadyr
# Processing Record 8 of Set 11 | zhanaozen
# Processing Record 9 of Set 11 | linxia
# Processing Record 10 of Set 11 | panzhihua
# Processing Record 11 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 11 | kuah
# Processing Record 13 of Set 11 | chapada dos guimaraes
# Processing Record 14 of Set 11 | antalaha
# Processing Record 15 of Set 11 | rincon
# Processing Record 16 of Set 11 | uttaradit
# Processing Record 17 of Set 11 | mitu
# Processing Record 18 of Set 11 | isangel
# Processing Record 19 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 11 | prince rupert
# Processing Record 21 of Set 11 | strezhevoy
# Processing Record 22 of Set 11 | staropesterevo
# Processing Record 23 of Set 11 | kichera
# Processing Record 24 of Set 11 | rio grande
# Processing Record 25 of Set 11 | moba
# Processing Record 26 of Set 11 | aykhal
# Processing Record 27 of Set 11 | seoul
# Processing Record 28 of Set 11 | severo-yeniseyskiy
# Processing Record 29 of Set 11 | vikevag
# Processing Record 30 of Set 11 | algete
# Processing Record 31 of Set 11 | saint-ambroise
# Processing Record 32 of Set 11 | geraldton
# Processing Record 33 of Set 11 | harlingen
# Processing Record 34 of Set 11 | caldwell
# Processing Record 35 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 11 | bayanday
# Processing Record 37 of Set 11 | englewood
# Processing Record 38 of Set 11 | kalmunai
# Processing Record 39 of Set 11 | snyder
# Processing Record 40 of Set 11 | port hueneme
# Processing Record 41 of Set 11 | college
# Processing Record 42 of Set 11 | kemijarvi
# Processing Record 43 of Set 11 | canmore
# Processing Record 44 of Set 11 | umm lajj
# Processing Record 45 of Set 11 | pitimbu
# Processing Record 46 of Set 11 | lyudinovo
# Processing Record 47 of Set 11 | pitea
# Processing Record 48 of Set 11 | dossor
# Processing Record 49 of Set 11 | marsa matruh
# Processing Record 50 of Set 11 | sakharovo
# Processing Record 1 of Set 12 | mehamn
# Processing Record 2 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 12 | iranshahr
# Processing Record 4 of Set 12 | port blair
# Processing Record 5 of Set 12 | chestermere
# Processing Record 6 of Set 12 | krasnoselkup
# Processing Record 7 of Set 12 | nemuro
# Processing Record 8 of Set 12 | rimini
# Processing Record 9 of Set 12 | ust-kut
# Processing Record 10 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 12 | gatak
# Processing Record 12 of Set 12 | gewane
# Processing Record 13 of Set 12 | isiro
# Processing Record 14 of Set 12 | vaitape
# Processing Record 15 of Set 12 | canavieiras
# Processing Record 16 of Set 12 | qaqortoq
# Processing Record 17 of Set 12 | sanica
# Processing Record 18 of Set 12 | rodrigues alves
# Processing Record 19 of Set 12 | brae
# Processing Record 20 of Set 12 | wattegama
# Processing Record 21 of Set 12 | tilichiki
# Processing Record 22 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 12 | arlit
# Processing Record 24 of Set 12 | valparaiso
# Processing Record 25 of Set 12 | haines junction
# Processing Record 26 of Set 12 | santa cruz
# Processing Record 27 of Set 12 | troy
# Processing Record 28 of Set 12 | comarapa
# Processing Record 29 of Set 12 | hwange
# Processing Record 30 of Set 12 | katangli
# Processing Record 31 of Set 12 | mandapam
# Processing Record 32 of Set 12 | mogok
# Processing Record 33 of Set 12 | ganzhou
# Processing Record 34 of Set 12 | maniitsoq
# Processing Record 35 of Set 12 | yamada
# Processing Record 36 of Set 12 | los llanos de aridane
# Processing Record 37 of Set 12 | dosso
# Processing Record 38 of Set 12 | winston-salem
# Processing Record 39 of Set 12 | chengde
# Processing Record 40 of Set 12 | glendive
# Processing Record 41 of Set 12 | wakkanai
# Processing Record 42 of Set 12 | alihe
# Processing Record 43 of Set 12 | bubaque
# Processing Record 44 of Set 12 | mgandu
# Processing Record 45 of Set 12 | yuzhno-kurilsk
# Processing Record 46 of Set 12 | shimoda
# Processing Record 47 of Set 12 | bismil
# Processing Record 48 of Set 12 | marsh harbour
# Processing Record 49 of Set 12 | belogorsk
# Processing Record 50 of Set 12 | povenets
# Processing Record 1 of Set 13 | batagay
# Processing Record 2 of Set 13 | bud
# Processing Record 3 of Set 13 | saraland
# Processing Record 4 of Set 13 | punta gorda
# Processing Record 5 of Set 13 | saquena
# Processing Record 6 of Set 13 | dalvik
# Processing Record 7 of Set 13 | kamenka
# Processing Record 8 of Set 13 | gladstone
# Processing Record 9 of Set 13 | kristiinankaupunki
# Processing Record 10 of Set 13 | vuktyl
# Processing Record 11 of Set 13 | casper
# Processing Record 12 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 13 | umm kaddadah
# Processing Record 14 of Set 13 | aransas pass
# Processing Record 15 of Set 13 | tabou
# Processing Record 16 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 13 | lixourion
# Processing Record 18 of Set 13 | aykino
# Processing Record 19 of Set 13 | alyangula
# Processing Record 20 of Set 13 | beloha
# Processing Record 21 of Set 13 | buarcos
# Processing Record 22 of Set 13 | beni
# Processing Record 23 of Set 13 | banda aceh
# Processing Record 24 of Set 13 | at-bashi
# Processing Record 25 of Set 13 | mishelevka
# Processing Record 26 of Set 13 | angoram
# Processing Record 27 of Set 13 | hargeysa
# Processing Record 28 of Set 13 | verkhnetulomskiy
# Processing Record 29 of Set 13 | nehe
# Processing Record 30 of Set 13 | terrace
# Processing Record 31 of Set 13 | swift current
# Processing Record 32 of Set 13 | amapa
# Processing Record 33 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 34 of Set 13 | farmington
# Processing Record 35 of Set 13 | sorland
# Processing Record 36 of Set 13 | jacareacanga
# Processing Record 37 of Set 13 | sao gabriel da cachoeira
# Processing Record 38 of Set 13 | riyadh
# Processing Record 39 of Set 13 | russkaya polyana
# Processing Record 40 of Set 13 | port macquarie
# Processing Record 41 of Set 13 | aranda de duero
# Processing Record 42 of Set 13 | kachiry
# Processing Record 43 of Set 13 | turangi
# Processing Record 44 of Set 13 | kalavad
# Processing Record 45 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 13 | ancud
# Processing Record 47 of Set 13 | ouesso
# Processing Record 48 of Set 13 | micheweni
# Processing Record 49 of Set 13 | garmsar
# Processing Record 50 of Set 13 | palana
# Processing Record 1 of Set 14 | upata
# Processing Record 2 of Set 14 | daoukro
# Processing Record 3 of Set 14 | chumikan
# Processing Record 4 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 14 | rjukan
# Processing Record 6 of Set 14 | kalabo
# Processing Record 7 of Set 14 | marquette
# Processing Record 8 of Set 14 | esperantina
# Processing Record 9 of Set 14 | khromtau
# Processing Record 10 of Set 14 | balikpapan
# Processing Record 11 of Set 14 | jimeta
# Processing Record 12 of Set 14 | galesong
# Processing Record 13 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 14 | antri
# Processing Record 16 of Set 14 | zhuhai
# Processing Record 17 of Set 14 | huarmey
# Processing Record 18 of Set 14 | bairiki
# Processing Record 19 of Set 14 | hami
# Processing Record 20 of Set 14 | kiunga
# Processing Record 21 of Set 14 | zhezkazgan
# Processing Record 22 of Set 14 | dedza
# Processing Record 23 of Set 14 | uthal
# Processing Record 24 of Set 14 | dumas
# Processing Record 25 of Set 14 | ternate
# Processing Record 26 of Set 14 | san quintin
# Processing Record 27 of Set 14 | ewa beach
# Processing Record 28 of Set 14 | boa esperanca
# Processing Record 29 of Set 14 | urumqi
# Processing Record 30 of Set 14 | namatanai
# Processing Record 31 of Set 14 | poplar bluff
# Processing Record 32 of Set 14 | faya
# Processing Record 33 of Set 14 | seagoville
# Processing Record 34 of Set 14 | huoqiu
# Processing Record 35 of Set 14 | flinders
# Processing Record 36 of Set 14 | lakes entrance
# Processing Record 37 of Set 14 | eyl
# Processing Record 38 of Set 14 | plettenberg bay
# Processing Record 39 of Set 14 | bardiyah
# Processing Record 40 of Set 14 | ucluelet
# Processing Record 41 of Set 14 | ayan
# Processing Record 42 of Set 14 | molchanovo
# Processing Record 43 of Set 14 | tukrah
# Processing Record 44 of Set 14 | mbekenyera
# Processing Record 45 of Set 14 | gogrial
# Processing Record 46 of Set 14 | mangan
# Processing Record 47 of Set 14 | bajil
# Processing Record 48 of Set 14 | tera
# Processing Record 49 of Set 14 | okhotsk
# Processing Record 50 of Set 14 | ruzhyn
# Processing Record 1 of Set 15 | kalangala
# Processing Record 2 of Set 15 | kumluca
# Processing Record 3 of Set 15 | teguldet
# Processing Record 4 of Set 15 | ormond beach
# Processing Record 5 of Set 15 | banepa
# Processing Record 6 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 15 | susuman
# Processing Record 8 of Set 15 | manavalakurichi
# Processing Record 9 of Set 15 | fairbanks
# Processing Record 10 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 15 | port augusta
# Processing Record 12 of Set 15 | edd
# Processing Record 13 of Set 15 | ponta delgada
# Processing Record 14 of Set 15 | richmond hill
# Processing Record 15 of Set 15 | shakiso
# Processing Record 16 of Set 15 | nikel
# Processing Record 17 of Set 15 | alta floresta
# Processing Record 18 of Set 15 | chkalovskoye
# Processing Record 19 of Set 15 | pachino
# Processing Record 20 of Set 15 | dombarovskiy
# Processing Record 21 of Set 15 | lincoln
# Processing Record 22 of Set 15 | saedinenie
# Processing Record 23 of Set 15 | piterka
# Processing Record 24 of Set 15 | berbera
# Processing Record 25 of Set 15 | qianjiang
# Processing Record 26 of Set 15 | shieli
# Processing Record 27 of Set 15 | camopi
# Processing Record 28 of Set 15 | ibra
# Processing Record 29 of Set 15 | illela
# Processing Record 30 of Set 15 | omsukchan
# Processing Record 31 of Set 15 | along
# Processing Record 32 of Set 15 | napier
# Processing Record 33 of Set 15 | san rafael
# Processing Record 34 of Set 15 | senanga
# Processing Record 35 of Set 15 | patiya
# Processing Record 36 of Set 15 | akniste
# Processing Record 37 of Set 15 | graaff-reinet
# Processing Record 38 of Set 15 | naze
# Processing Record 39 of Set 15 | natchez
# Processing Record 40 of Set 15 | caravelas
# Processing Record 41 of Set 15 | salta
# Processing Record 42 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 43 of Set 15 | komsomolskiy
# Processing Record 44 of Set 15 | westport
# Processing Record 45 of Set 15 | jos
# Processing Record 46 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 15 | mangrol
# Processing Record 48 of Set 15 | neiafu
# Processing Record 49 of Set 15 | saint-francois
# Processing Record 50 of Set 15 | porto santo
# Processing Record 1 of Set 16 | pangody
# Processing Record 2 of Set 16 | charleston
# Processing Record 3 of Set 16 | ipameri
# Processing Record 4 of Set 16 | kuito
# Processing Record 5 of Set 16 | buta
# Processing Record 6 of Set 16 | ahipara
# Processing Record 7 of Set 16 | otane
# Processing Record 8 of Set 16 | kimberley
# Processing Record 9 of Set 16 | devyatka
# City not found. Skipping...
# Processing Record 10 of Set 16 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 16 | magalia
# Processing Record 12 of Set 16 | isabela
# Processing Record 13 of Set 16 | mchinji
# Processing Record 14 of Set 16 | amahai
# Processing Record 15 of Set 16 | dormidontovka
# Processing Record 16 of Set 16 | laguna de perlas
# Processing Record 17 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 16 | mancio lima
# Processing Record 19 of Set 16 | baylo
# Processing Record 20 of Set 16 | vallenar
# Processing Record 21 of Set 16 | maloshuyka
# City not found. Skipping...
# Processing Record 22 of Set 16 | shuyskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Maldonado      UY -34.6667  -54.9167     51.19        92           0
# 1  Punta Arenas      CL -53.1500  -70.9167     42.91        81          75
# 2       Litovko      RU  49.2361  135.1742     43.95        39          21
# 3        Quepos      CR   9.4236  -84.1652     76.46        89         100
# 4     Jamestown      US  42.0970  -79.2353     49.64        67           0
#
#    Wind Speed Current Description
# 0        5.41           clear sky
# 1       17.27       broken clouds
# 2       16.46          few clouds
# 3        0.92     overcast clouds
# 4       10.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
